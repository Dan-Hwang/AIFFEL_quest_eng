# %%
import random # Q1 계좌번호 랜덤 생성 모듈 불러오기

class Account: # Q1 클래스 생성
    bank_name ='SC은행' # Q1 은행이름 고정
    account_num = 0 # Q2 처음 계좌 수 지정
    
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

        num1 = random.randint(100, 999)
        num2 = random.randint(10, 99)
        num3 = random.randint(100000, 999999)
        self.account_number = str(num1) + '-' + str(num2) + '-' + str(num3) # Q1 '-'와 합치기 위해 str로 처리

        Account.account_num += 1

    def get_account_num(self): # Q3
        print(Account.account_num)

    def deposit(self): # Q4
        while True:
            try:
                amount = int(input('입금할 금액을 입력하세요.'))
                
                if amount >= 1:
                    self.balance += amount
                    break
                
                else:
                    print('입금은 최소 1원 이상만 가능합니다.')
            
            except ValueError:
                print('입금은 최소 1원 이상만 가능합니다.')

# %%
a = Account('철수', 1000)
print(a.balance)   # 시작 잔고 확인
a.deposit()        # 입금 실행
print(a.balance)   # 바뀐 잔고 확인
# Out:
# 1000
# 입금할 금액을 입력하세요. 1100
# 2100
